# %%
import pandas as pd
# DEFINE LA RUTA
ruta = r"C:\Users\brv_1\Documents\Programacion\PORTAFOLIOS\DASHBOARDS\CALIDAD_AGUA\database\Base_Calidad_Agua_5000_Registros.csv"
df = pd.read_csv(ruta)

df.describe()
# Out:
#                 pH           OD    Turbidez  Conductividad     Nitratos
# count  5000.000000  5000.000000  5000.00000    5000.000000  5000.000000
# mean      7.454484     7.133292    11.59354     552.592360     2.943006
# std       0.293488     1.207011     4.45360     206.846221     2.684185
# min       6.540000     4.080000     0.50000     174.700000     0.050000
# 25%       7.240000     6.160000     8.40000     379.200000     0.910000
# 50%       7.450000     7.160000    11.30000     508.000000     1.770000
# 75%       7.670000     8.110000    14.70000     702.725000     4.630000
# max       8.340000    10.170000    29.30000    1040.600000    10.140000
